# %%
from pulp import LpMaximize, LpMinimize, LpProblem, LpStatus, lpSum, LpVariable
import pandas as pd

# %% [markdown]
# In the undergraduate honors program at PNU, students bid for internships in the final year of their program.  Each student has 100 total points to bid and must complete two internships.  Each internship is limited to five students.  The bids submitted by each of the 15 students in the program for the seven available internships are contained in the data file HW2_BidData.csv.
#
# Build a model that can be used to assign students to internships in order to maximize the total bid points for all students given their assignments.
#
# Solve the model for which internship assignments each student receives in the optimal solution.

# %%
data = pd.read_csv('HW2_BidData.csv')
data = data.set_index('Student')
data
# Out:
#          Quest_Realty  CTG_Associates  Innova  Celeron_Capital  Helder_LLC  \
# Student
# Kevin              80               0       0                0           0
# Ayush              10               0      40               20           5
# Zan                45              45       0                5           0
# Kim                 0              20       5               25          50
# Daria              30               0      30               10           0
# Yogesh              0              50       0                0          50
# Bonita              0              20      10               70           0
# Elayne             25               0      35               15           0
# Segev              10              15      35               15           0
# Abeer              20              10      10               20           0
# Wei                 0              10      10               40          40
# Yilin               0              70       0                0          20
# Jeroen             40               0      10               10          40
# Yasmeen             5               5       0                0          30
# Kristen            50               0       0               40           0
#
#          Felsen_Davis  Sienna_Financial_Group
# Student
# Kevin              10                      10
# Ayush              15                       0
# Zan                 5                       0
# Kim                 0                       0
# Daria               0                      30
# Yogesh              0                       0
# Bonita              0                       0
# Elayne             25                       0
# Segev              25                       0
# Abeer              20                      20
# Wei                 0                       0
# Yilin               5                       0
# Jeroen              0                       0
# Yasmeen             0                      60
# Kristen            10                       0

# %%
model = LpProblem("Internship_Bids", LpMaximize)

# %%
# Construct Decision Variables

Students = data.index
Internships = data.columns

Assignments = LpVariable.dicts("assign", ((s, i) for s in Students for i in Internships), cat = 'Binary')
Assignments
# Out:
# {('Kevin', 'Quest_Realty'): assign_('Kevin',_'Quest_Realty'),
#  ('Kevin', 'CTG_Associates'): assign_('Kevin',_'CTG_Associates'),
#  ('Kevin', 'Innova'): assign_('Kevin',_'Innova'),
#  ('Kevin', 'Celeron_Capital'): assign_('Kevin',_'Celeron_Capital'),
#  ('Kevin', 'Helder_LLC'): assign_('Kevin',_'Helder_LLC'),
#  ('Kevin', 'Felsen_Davis'): assign_('Kevin',_'Felsen_Davis'),
#  ('Kevin',
#   'Sienna_Financial_Group'): assign_('Kevin',_'Sienna_Financial_Group'),
#  ('Ayush', 'Quest_Realty'): assign_('Ayush',_'Quest_Realty'),
#  ('Ayush', 'CTG_Associates'): assign_('Ayush',_'CTG_Associates'),
#  ('Ayush', 'Innova'): assign_('Ayush',_'Innova'),
#  ('Ayush', 'Celeron_Capital'): assign_('Ayush',_'Celeron_Capital'),
#  ('Ayush', 'Helder_LLC'): assign_('Ayush',_'Helder_LLC'),
#  ('Ayush', 'Felsen_Davis'): assign_('Ayush',_'Felsen_Davis'),
#  ('Ayush',
#   'Sienna_Financial_Group'): assign_('Ayush',_'Sienna_Financial_Group'),
#  ('Zan', 'Quest_Realty'): assign_('Zan',_'Quest_Realty'),
#  ('Zan', 'CTG_Associates'): assign_('Zan',_'CTG_Associates'),
#  ('Zan', 'Innova'): assign_('Zan',_'Innova'),
#  ('Zan', 'Celeron_Capital'): assign_('Zan',_'Celeron_Capital'),
#  ('Zan', 'Helder_LLC'): assign_('Zan',_'Helder_LLC'),
#  ('Zan', 'Felsen_Davis'): assign_('Zan',_'Felsen_Davis'),
#  ('Zan', 'Sienna_Financial_Group'): assign_('Zan',_'Sienna_Financial_Group'),
#  ('Kim', 'Quest_Realty'): assign_('Kim',_'Quest_Realty'),
#  ('Kim', 'CTG_Associates'): assign_('Kim',_'CTG_Associates'),
#  ('Kim', 'Innova'): assign_('Kim',_'Innova'),
#  ('Kim', 'Celeron_Capital'): assign_('Kim',_'Celeron_Capital'),
#  ('Kim', 'Helder_LLC'): assign_('Kim',_'Helder_LLC'),
#  ('Kim', 'Felsen_Davis'): assign_('Kim',_'Felsen_Davis'),
#  ('Kim', 'Sienna_Financial_Group'): assign_('Kim',_'Sienna_Financial_Group'),
#  ('Daria', 'Quest_Realty'): assign_('Daria',_'Quest_Realty'),
#  ('Daria', 'CTG_Associates'): assign_('Daria',_'CTG_Associates'),
#  ('Daria', 'Innova'): assign_('Daria',_'Innova'),
#  ('Daria', 'Celeron_Capital'): assign_('Daria',_'Celeron_Capital'),
#  ('Daria', 'Helder_LLC'): assign_('Daria',_'Helder_LLC'),
#  ('Daria', 'Felsen_Davis'): assign_('Daria',_'Felsen_Davis'),
#  ('Daria',
#   'Sienna_Financial_Group'): assign_('Daria',_'Sienna_Financial_Group'),
#  ('Yogesh', 'Quest_Realty'): assign_('Yogesh',_'Quest_Realty'),
#  ('Yogesh', 'CTG_Associates'): assign_('Yogesh',_'CTG_Associates'),
#  ('Yogesh', 'Innova'): assign_('Yogesh',_'Innova'),
#  ('Yogesh', 'Celeron_Capital'): assign_('Yogesh',_'Celeron_Capital'),
#  ('Yogesh', 'Helder_LLC'): assign_('Yogesh',_'Helder_LLC'),
#  ('Yogesh', 'Felsen_Davis'): assign_('Yogesh',_'Felsen_Davis'),
#  ('Yogesh',
#   'Sienna_Financial_Group'): assign_('Yogesh',_'Sienna_Financial_Group'),
#  ('Bonita', 'Quest_Realty'): assign_('Bonita',_'Quest_Realty'),
#  ('Bonita', 'CTG_Associates'): assign_('Bonita',_'CTG_Associates'),
#  ('Bonita', 'Innova'): assign_('Bonita',_'Innova'),
#  ('Bonita', 'Celeron_Capital'): assign_('Bonita',_'Celeron_Capital'),
#  ('Bonita', 'Helder_LLC'): assign_('Bonita',_'Helder_LLC'),
#  ('Bonita', 'Felsen_Davis'): assign_('Bonita',_'Felsen_Davis'),
#  ('Bonita',
#   'Sienna_Financial_Group'): assign_('Bonita',_'Sienna_Financial_Group'),
#  ('Elayne', 'Quest_Realty'): assign_('Elayne',_'Quest_Realty'),
#  ('Elayne', 'CTG_Associates'): assign_('Elayne',_'CTG_Associates'),
#  ('Elayne', 'Innova'): assign_('Elayne',_'Innova'),
#  ('Elayne', 'Celeron_Capital'): assign_('Elayne',_'Celeron_Capital'),
#  ('Elayne', 'Helder_LLC'): assign_('Elayne',_'Helder_LLC'),
#  ('Elayne', 'Felsen_Davis'): assign_('Elayne',_'Felsen_Davis'),
#  ('Elayne',
#   'Sienna_Financial_Group'): assign_('Elayne',_'Sienna_Financial_Group'),
#  ('Segev', 'Quest_Realty'): assign_('Segev',_'Quest_Realty'),
#  ('Segev', 'CTG_Associates'): assign_('Segev',_'CTG_Associates'),
#  ('Segev', 'Innova'): assign_('Segev',_'Innova'),
#  ('Segev', 'Celeron_Capital'): assign_('Segev',_'Celeron_Capital'),
#  ('Segev', 'Helder_LLC'): assign_('Segev',_'Helder_LLC'),
#  ('Segev', 'Felsen_Davis'): assign_('Segev',_'Felsen_Davis'),
#  ('Segev',
#   'Sienna_Financial_Group'): assign_('Segev',_'Sienna_Financial_Group'),
#  ('Abeer', 'Quest_Realty'): assign_('Abeer',_'Quest_Realty'),
#  ('Abeer', 'CTG_Associates'): assign_('Abeer',_'CTG_Associates'),
#  ('Abeer', 'Innova'): assign_('Abeer',_'Innova'),
#  ('Abeer', 'Celeron_Capital'): assign_('Abeer',_'Celeron_Capital'),
#  ('Abeer', 'Helder_LLC'): assign_('Abeer',_'Helder_LLC'),
#  ('Abeer', 'Felsen_Davis'): assign_('Abeer',_'Felsen_Davis'),
#  ('Abeer',
#   'Sienna_Financial_Group'): assign_('Abeer',_'Sienna_Financial_Group'),
#  ('Wei', 'Quest_Realty'): assign_('Wei',_'Quest_Realty'),
#  ('Wei', 'CTG_Associates'): assign_('Wei',_'CTG_Associates'),
#  ('Wei', 'Innova'): assign_('Wei',_'Innova'),
#  ('Wei', 'Celeron_Capital'): assign_('Wei',_'Celeron_Capital'),
#  ('Wei', 'Helder_LLC'): assign_('Wei',_'Helder_LLC'),
#  ('Wei', 'Felsen_Davis'): assign_('Wei',_'Felsen_Davis'),
#  ('Wei', 'Sienna_Financial_Group'): assign_('Wei',_'Sienna_Financial_Group'),
#  ('Yilin', 'Quest_Realty'): assign_('Yilin',_'Quest_Realty'),
#  ('Yilin', 'CTG_Associates'): assign_('Yilin',_'CTG_Associates'),
#  ('Yilin', 'Innova'): assign_('Yilin',_'Innova'),
#  ('Yilin', 'Celeron_Capital'): assign_('Yilin',_'Celeron_Capital'),
#  ('Yilin', 'Helder_LLC'): assign_('Yilin',_'Helder_LLC'),
#  ('Yilin', 'Felsen_Davis'): assign_('Yilin',_'Felsen_Davis'),
#  ('Yilin',
#   'Sienna_Financial_Group'): assign_('Yilin',_'Sienna_Financial_Group'),
#  ('Jeroen', 'Quest_Realty'): assign_('Jeroen',_'Quest_Realty'),
#  ('Jeroen', 'CTG_Associates'): assign_('Jeroen',_'CTG_Associates'),
#  ('Jeroen', 'Innova'): assign_('Jeroen',_'Innova'),
#  ('Jeroen', 'Celeron_Capital'): assign_('Jeroen',_'Celeron_Capital'),
#  ('Jeroen', 'Helder_LLC'): assign_('Jeroen',_'Helder_LLC'),
#  ('Jeroen', 'Felsen_Davis'): assign_('Jeroen',_'Felsen_Davis'),
#  ('Jeroen',
#   'Sienna_Financial_Group'): assign_('Jeroen',_'Sienna_Financial_Group'),
#  ('Yasmeen', 'Quest_Realty'): assign_('Yasmeen',_'Quest_Realty'),
#  ('Yasmeen', 'CTG_Associates'): assign_('Yasmeen',_'CTG_Associates'),
#  ('Yasmeen', 'Innova'): assign_('Yasmeen',_'Innova'),
#  ('Yasmeen', 'Celeron_Capital'): assign_('Yasmeen',_'Celeron_Capital'),
#  ('Yasmeen', 'Helder_LLC'): assign_('Yasmeen',_'Helder_LLC'),
#  ('Yasmeen', 'Felsen_Davis'): assign_('Yasmeen',_'Felsen_Davis'),
#  ('Yasmeen',
#   'Sienna_Financial_Group'): assign_('Yasmeen',_'Sienna_Financial_Group'),
#  ('Kristen', 'Quest_Realty'): assign_('Kristen',_'Quest_Realty'),
#  ('Kristen', 'CTG_Associates'): assign_('Kristen',_'CTG_Associates'),
#  ('Kristen', 'Innova'): assign_('Kristen',_'Innova'),
#  ('Kristen', 'Celeron_Capital'): assign_('Kristen',_'Celeron_Capital'),
#  ('Kristen', 'Helder_LLC'): assign_('Kristen',_'Helder_LLC'),
#  ('Kristen', 'Felsen_Davis'): assign_('Kristen',_'Felsen_Davis'),
#  ('Kristen',
#   'Sienna_Financial_Group'): assign_('Kristen',_'Sienna_Financial_Group')}

# %%
# Add the objective function to the model
model += lpSum(data.loc[s, i] * Assignments[s, i] for s in Students for i in Internships)
model
# Out:
# Internship_Bids:
# MAXIMIZE
# 10*assign_('Abeer',_'CTG_Associates') + 20*assign_('Abeer',_'Celeron_Capital') + 20*assign_('Abeer',_'Felsen_Davis') + 10*assign_('Abeer',_'Innova') + 20*assign_('Abeer',_'Quest_Realty') + 20*assign_('Abeer',_'Sienna_Financial_Group') + 20*assign_('Ayush',_'Celeron_Capital') + 15*assign_('Ayush',_'Felsen_Davis') + 5*assign_('Ayush',_'Helder_LLC') + 40*assign_('Ayush',_'Innova') + 10*assign_('Ayush',_'Quest_Realty') + 20*assign_('Bonita',_'CTG_Associates') + 70*assign_('Bonita',_'Celeron_Capital') + 10*assign_('Bonita',_'Innova') + 10*assign_('Daria',_'Celeron_Capital') + 30*assign_('Daria',_'Innova') + 30*assign_('Daria',_'Quest_Realty') + 30*assign_('Daria',_'Sienna_Financial_Group') + 15*assign_('Elayne',_'Celeron_Capital') + 25*assign_('Elayne',_'Felsen_Davis') + 35*assign_('Elayne',_'Innova') + 25*assign_('Elayne',_'Quest_Realty') + 10*assign_('Jeroen',_'Celeron_Capital') + 40*assign_('Jeroen',_'Helder_LLC') + 10*assign_('Jeroen',_'Innova') + 40*assign_('Jeroen',_'Quest_Realty') + 10*assign_('Kevin',_'Felsen_Davis') + 80*assign_('Kevin',_'Quest_Realty') + 10*assign_('Kevin',_'Sienna_Financial_Group') + 20*assign_('Kim',_'CTG_Associates') + 25*assign_('Kim',_'Celeron_Capital') + 50*assign_('Kim',_'Helder_LLC') + 5*assign_('Kim',_'Innova') + 40*assign_('Kristen',_'Celeron_Capital') + 10*assign_('Kristen',_'Felsen_Davis') + 50*assign_('Kristen',_'Quest_Realty') + 15*assign_('Segev',_'CTG_Associates') + 15*assign_('Segev',_'Celeron_Capital') + 25*assign_('Segev',_'Felsen_Davis') + 35*assign_('Segev',_'Innova') + 10*assign_('Segev',_'Quest_Realty') + 10*assign_('Wei',_'CTG_Associates') + 40*assign_('Wei',_'Celeron_Capital') + 40*assign_('Wei',_'Helder_LLC') + 10*assign_('Wei',_'Innova') + 5*assign_('Yasmeen',_'CTG_Associates') + 30*assign_('Yasmeen',_'Helder_LLC') + 5*assign_('Yasmeen',_'Quest_Realty') + 60*assign_('Yasmeen',_'Sienna_Financial_Group') + 70*assign_('Yilin',_'CTG_Associates') + 5*assign_('Yilin',_'Felsen_Davis') + 20*assign_('Yilin',_'Helder_LLC') + 50*assign_('Yogesh',_'CTG_Associates') + 50*assign_('Yogesh',_'Helder_LLC') + 45*assign_('Zan',_'CTG_Associates') + 5*assign_('Zan',_'Celeron_Capital') + 5*assign_('Zan',_'Felsen_Davis') + 45*assign_('Zan',_'Quest_Realty') + 0
# VARIABLES
# 0 <= assign_('Abeer',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Abeer',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Abeer',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Abeer',_'Innova') <= 1 Integer
# 0 <= assign_('Abeer',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Abeer',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Ayush',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Ayush',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Ayush',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Ayush',_'Innova') <= 1 Integer
# 0 <= assign_('Ayush',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Bonita',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Bonita',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Bonita',_'Innova') <= 1 Integer
# 0 <= assign_('Daria',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Daria',_'Innova') <= 1 Integer
# 0 <= assign_('Daria',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Daria',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Elayne',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Elayne',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Elayne',_'Innova') <= 1 Integer
# 0 <= assign_('Elayne',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Jeroen',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Jeroen',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Jeroen',_'Innova') <= 1 Integer
# 0 <= assign_('Jeroen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Kevin',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Kevin',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Kevin',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Kim',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Kim',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Kim',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Kim',_'Innova') <= 1 Integer
# 0 <= assign_('Kristen',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Kristen',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Kristen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Segev',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Segev',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Segev',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Segev',_'Innova') <= 1 Integer
# 0 <= assign_('Segev',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Wei',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Wei',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Wei',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Wei',_'Innova') <= 1 Integer
# 0 <= assign_('Yasmeen',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Yilin',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yilin',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Yilin',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Yogesh',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yogesh',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Zan',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Zan',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Zan',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Zan',_'Quest_Realty') <= 1 Integer

# %%
# Add the constraints to the model

for s in Students:
    model += 2 == lpSum(Assignments[s, i] for i in Internships)

for i in Internships:
    model += 5 >= lpSum(Assignments[s, i] for s in Students)

# %%
model
# Out:
# Internship_Bids:
# MAXIMIZE
# 10*assign_('Abeer',_'CTG_Associates') + 20*assign_('Abeer',_'Celeron_Capital') + 20*assign_('Abeer',_'Felsen_Davis') + 10*assign_('Abeer',_'Innova') + 20*assign_('Abeer',_'Quest_Realty') + 20*assign_('Abeer',_'Sienna_Financial_Group') + 20*assign_('Ayush',_'Celeron_Capital') + 15*assign_('Ayush',_'Felsen_Davis') + 5*assign_('Ayush',_'Helder_LLC') + 40*assign_('Ayush',_'Innova') + 10*assign_('Ayush',_'Quest_Realty') + 20*assign_('Bonita',_'CTG_Associates') + 70*assign_('Bonita',_'Celeron_Capital') + 10*assign_('Bonita',_'Innova') + 10*assign_('Daria',_'Celeron_Capital') + 30*assign_('Daria',_'Innova') + 30*assign_('Daria',_'Quest_Realty') + 30*assign_('Daria',_'Sienna_Financial_Group') + 15*assign_('Elayne',_'Celeron_Capital') + 25*assign_('Elayne',_'Felsen_Davis') + 35*assign_('Elayne',_'Innova') + 25*assign_('Elayne',_'Quest_Realty') + 10*assign_('Jeroen',_'Celeron_Capital') + 40*assign_('Jeroen',_'Helder_LLC') + 10*assign_('Jeroen',_'Innova') + 40*assign_('Jeroen',_'Quest_Realty') + 10*assign_('Kevin',_'Felsen_Davis') + 80*assign_('Kevin',_'Quest_Realty') + 10*assign_('Kevin',_'Sienna_Financial_Group') + 20*assign_('Kim',_'CTG_Associates') + 25*assign_('Kim',_'Celeron_Capital') + 50*assign_('Kim',_'Helder_LLC') + 5*assign_('Kim',_'Innova') + 40*assign_('Kristen',_'Celeron_Capital') + 10*assign_('Kristen',_'Felsen_Davis') + 50*assign_('Kristen',_'Quest_Realty') + 15*assign_('Segev',_'CTG_Associates') + 15*assign_('Segev',_'Celeron_Capital') + 25*assign_('Segev',_'Felsen_Davis') + 35*assign_('Segev',_'Innova') + 10*assign_('Segev',_'Quest_Realty') + 10*assign_('Wei',_'CTG_Associates') + 40*assign_('Wei',_'Celeron_Capital') + 40*assign_('Wei',_'Helder_LLC') + 10*assign_('Wei',_'Innova') + 5*assign_('Yasmeen',_'CTG_Associates') + 30*assign_('Yasmeen',_'Helder_LLC') + 5*assign_('Yasmeen',_'Quest_Realty') + 60*assign_('Yasmeen',_'Sienna_Financial_Group') + 70*assign_('Yilin',_'CTG_Associates') + 5*assign_('Yilin',_'Felsen_Davis') + 20*assign_('Yilin',_'Helder_LLC') + 50*assign_('Yogesh',_'CTG_Associates') + 50*assign_('Yogesh',_'Helder_LLC') + 45*assign_('Zan',_'CTG_Associates') + 5*assign_('Zan',_'Celeron_Capital') + 5*assign_('Zan',_'Felsen_Davis') + 45*assign_('Zan',_'Quest_Realty') + 0
# SUBJECT TO
# _C1: assign_('Kevin',_'CTG_Associates') + assign_('Kevin',_'Celeron_Capital')
#  + assign_('Kevin',_'Felsen_Davis') + assign_('Kevin',_'Helder_LLC')
#  + assign_('Kevin',_'Innova') + assign_('Kevin',_'Quest_Realty')
#  + assign_('Kevin',_'Sienna_Financial_Group') = 2
#
# _C2: assign_('Ayush',_'CTG_Associates') + assign_('Ayush',_'Celeron_Capital')
#  + assign_('Ayush',_'Felsen_Davis') + assign_('Ayush',_'Helder_LLC')
#  + assign_('Ayush',_'Innova') + assign_('Ayush',_'Quest_Realty')
#  + assign_('Ayush',_'Sienna_Financial_Group') = 2
#
# _C3: assign_('Zan',_'CTG_Associates') + assign_('Zan',_'Celeron_Capital')
#  + assign_('Zan',_'Felsen_Davis') + assign_('Zan',_'Helder_LLC')
#  + assign_('Zan',_'Innova') + assign_('Zan',_'Quest_Realty')
#  + assign_('Zan',_'Sienna_Financial_Group') = 2
#
# _C4: assign_('Kim',_'CTG_Associates') + assign_('Kim',_'Celeron_Capital')
#  + assign_('Kim',_'Felsen_Davis') + assign_('Kim',_'Helder_LLC')
#  + assign_('Kim',_'Innova') + assign_('Kim',_'Quest_Realty')
#  + assign_('Kim',_'Sienna_Financial_Group') = 2
#
# _C5: assign_('Daria',_'CTG_Associates') + assign_('Daria',_'Celeron_Capital')
#  + assign_('Daria',_'Felsen_Davis') + assign_('Daria',_'Helder_LLC')
#  + assign_('Daria',_'Innova') + assign_('Daria',_'Quest_Realty')
#  + assign_('Daria',_'Sienna_Financial_Group') = 2
#
# _C6: assign_('Yogesh',_'CTG_Associates')
#  + assign_('Yogesh',_'Celeron_Capital') + assign_('Yogesh',_'Felsen_Davis')
#  + assign_('Yogesh',_'Helder_LLC') + assign_('Yogesh',_'Innova')
#  + assign_('Yogesh',_'Quest_Realty')
#  + assign_('Yogesh',_'Sienna_Financial_Group') = 2
#
# _C7: assign_('Bonita',_'CTG_Associates')
#  + assign_('Bonita',_'Celeron_Capital') + assign_('Bonita',_'Felsen_Davis')
#  + assign_('Bonita',_'Helder_LLC') + assign_('Bonita',_'Innova')
#  + assign_('Bonita',_'Quest_Realty')
#  + assign_('Bonita',_'Sienna_Financial_Group') = 2
#
# _C8: assign_('Elayne',_'CTG_Associates')
#  + assign_('Elayne',_'Celeron_Capital') + assign_('Elayne',_'Felsen_Davis')
#  + assign_('Elayne',_'Helder_LLC') + assign_('Elayne',_'Innova')
#  + assign_('Elayne',_'Quest_Realty')
#  + assign_('Elayne',_'Sienna_Financial_Group') = 2
#
# _C9: assign_('Segev',_'CTG_Associates') + assign_('Segev',_'Celeron_Capital')
#  + assign_('Segev',_'Felsen_Davis') + assign_('Segev',_'Helder_LLC')
#  + assign_('Segev',_'Innova') + assign_('Segev',_'Quest_Realty')
#  + assign_('Segev',_'Sienna_Financial_Group') = 2
#
# _C10: assign_('Abeer',_'CTG_Associates') + assign_('Abeer',_'Celeron_Capital')
#  + assign_('Abeer',_'Felsen_Davis') + assign_('Abeer',_'Helder_LLC')
#  + assign_('Abeer',_'Innova') + assign_('Abeer',_'Quest_Realty')
#  + assign_('Abeer',_'Sienna_Financial_Group') = 2
#
# _C11: assign_('Wei',_'CTG_Associates') + assign_('Wei',_'Celeron_Capital')
#  + assign_('Wei',_'Felsen_Davis') + assign_('Wei',_'Helder_LLC')
#  + assign_('Wei',_'Innova') + assign_('Wei',_'Quest_Realty')
#  + assign_('Wei',_'Sienna_Financial_Group') = 2
#
# _C12: assign_('Yilin',_'CTG_Associates') + assign_('Yilin',_'Celeron_Capital')
#  + assign_('Yilin',_'Felsen_Davis') + assign_('Yilin',_'Helder_LLC')
#  + assign_('Yilin',_'Innova') + assign_('Yilin',_'Quest_Realty')
#  + assign_('Yilin',_'Sienna_Financial_Group') = 2
#
# _C13: assign_('Jeroen',_'CTG_Associates')
#  + assign_('Jeroen',_'Celeron_Capital') + assign_('Jeroen',_'Felsen_Davis')
#  + assign_('Jeroen',_'Helder_LLC') + assign_('Jeroen',_'Innova')
#  + assign_('Jeroen',_'Quest_Realty')
#  + assign_('Jeroen',_'Sienna_Financial_Group') = 2
#
# _C14: assign_('Yasmeen',_'CTG_Associates')
#  + assign_('Yasmeen',_'Celeron_Capital') + assign_('Yasmeen',_'Felsen_Davis')
#  + assign_('Yasmeen',_'Helder_LLC') + assign_('Yasmeen',_'Innova')
#  + assign_('Yasmeen',_'Quest_Realty')
#  + assign_('Yasmeen',_'Sienna_Financial_Group') = 2
#
# _C15: assign_('Kristen',_'CTG_Associates')
#  + assign_('Kristen',_'Celeron_Capital') + assign_('Kristen',_'Felsen_Davis')
#  + assign_('Kristen',_'Helder_LLC') + assign_('Kristen',_'Innova')
#  + assign_('Kristen',_'Quest_Realty')
#  + assign_('Kristen',_'Sienna_Financial_Group') = 2
#
# _C16: assign_('Abeer',_'Quest_Realty') + assign_('Ayush',_'Quest_Realty')
#  + assign_('Bonita',_'Quest_Realty') + assign_('Daria',_'Quest_Realty')
#  + assign_('Elayne',_'Quest_Realty') + assign_('Jeroen',_'Quest_Realty')
#  + assign_('Kevin',_'Quest_Realty') + assign_('Kim',_'Quest_Realty')
#  + assign_('Kristen',_'Quest_Realty') + assign_('Segev',_'Quest_Realty')
#  + assign_('Wei',_'Quest_Realty') + assign_('Yasmeen',_'Quest_Realty')
#  + assign_('Yilin',_'Quest_Realty') + assign_('Yogesh',_'Quest_Realty')
#  + assign_('Zan',_'Quest_Realty') <= 5
#
# _C17: assign_('Abeer',_'CTG_Associates') + assign_('Ayush',_'CTG_Associates')
#  + assign_('Bonita',_'CTG_Associates') + assign_('Daria',_'CTG_Associates')
#  + assign_('Elayne',_'CTG_Associates') + assign_('Jeroen',_'CTG_Associates')
#  + assign_('Kevin',_'CTG_Associates') + assign_('Kim',_'CTG_Associates')
#  + assign_('Kristen',_'CTG_Associates') + assign_('Segev',_'CTG_Associates')
#  + assign_('Wei',_'CTG_Associates') + assign_('Yasmeen',_'CTG_Associates')
#  + assign_('Yilin',_'CTG_Associates') + assign_('Yogesh',_'CTG_Associates')
#  + assign_('Zan',_'CTG_Associates') <= 5
#
# _C18: assign_('Abeer',_'Innova') + assign_('Ayush',_'Innova')
#  + assign_('Bonita',_'Innova') + assign_('Daria',_'Innova')
#  + assign_('Elayne',_'Innova') + assign_('Jeroen',_'Innova')
#  + assign_('Kevin',_'Innova') + assign_('Kim',_'Innova')
#  + assign_('Kristen',_'Innova') + assign_('Segev',_'Innova')
#  + assign_('Wei',_'Innova') + assign_('Yasmeen',_'Innova')
#  + assign_('Yilin',_'Innova') + assign_('Yogesh',_'Innova')
#  + assign_('Zan',_'Innova') <= 5
#
# _C19: assign_('Abeer',_'Celeron_Capital')
#  + assign_('Ayush',_'Celeron_Capital') + assign_('Bonita',_'Celeron_Capital')
#  + assign_('Daria',_'Celeron_Capital') + assign_('Elayne',_'Celeron_Capital')
#  + assign_('Jeroen',_'Celeron_Capital') + assign_('Kevin',_'Celeron_Capital')
#  + assign_('Kim',_'Celeron_Capital') + assign_('Kristen',_'Celeron_Capital')
#  + assign_('Segev',_'Celeron_Capital') + assign_('Wei',_'Celeron_Capital')
#  + assign_('Yasmeen',_'Celeron_Capital') + assign_('Yilin',_'Celeron_Capital')
#  + assign_('Yogesh',_'Celeron_Capital') + assign_('Zan',_'Celeron_Capital')
#  <= 5
#
# _C20: assign_('Abeer',_'Helder_LLC') + assign_('Ayush',_'Helder_LLC')
#  + assign_('Bonita',_'Helder_LLC') + assign_('Daria',_'Helder_LLC')
#  + assign_('Elayne',_'Helder_LLC') + assign_('Jeroen',_'Helder_LLC')
#  + assign_('Kevin',_'Helder_LLC') + assign_('Kim',_'Helder_LLC')
#  + assign_('Kristen',_'Helder_LLC') + assign_('Segev',_'Helder_LLC')
#  + assign_('Wei',_'Helder_LLC') + assign_('Yasmeen',_'Helder_LLC')
#  + assign_('Yilin',_'Helder_LLC') + assign_('Yogesh',_'Helder_LLC')
#  + assign_('Zan',_'Helder_LLC') <= 5
#
# _C21: assign_('Abeer',_'Felsen_Davis') + assign_('Ayush',_'Felsen_Davis')
#  + assign_('Bonita',_'Felsen_Davis') + assign_('Daria',_'Felsen_Davis')
#  + assign_('Elayne',_'Felsen_Davis') + assign_('Jeroen',_'Felsen_Davis')
#  + assign_('Kevin',_'Felsen_Davis') + assign_('Kim',_'Felsen_Davis')
#  + assign_('Kristen',_'Felsen_Davis') + assign_('Segev',_'Felsen_Davis')
#  + assign_('Wei',_'Felsen_Davis') + assign_('Yasmeen',_'Felsen_Davis')
#  + assign_('Yilin',_'Felsen_Davis') + assign_('Yogesh',_'Felsen_Davis')
#  + assign_('Zan',_'Felsen_Davis') <= 5
#
# _C22: assign_('Abeer',_'Sienna_Financial_Group')
#  + assign_('Ayush',_'Sienna_Financial_Group')
#  + assign_('Bonita',_'Sienna_Financial_Group')
#  + assign_('Daria',_'Sienna_Financial_Group')
#  + assign_('Elayne',_'Sienna_Financial_Group')
#  + assign_('Jeroen',_'Sienna_Financial_Group')
#  + assign_('Kevin',_'Sienna_Financial_Group')
#  + assign_('Kim',_'Sienna_Financial_Group')
#  + assign_('Kristen',_'Sienna_Financial_Group')
#  + assign_('Segev',_'Sienna_Financial_Group')
#  + assign_('Wei',_'Sienna_Financial_Group')
#  + assign_('Yasmeen',_'Sienna_Financial_Group')
#  + assign_('Yilin',_'Sienna_Financial_Group')
#  + assign_('Yogesh',_'Sienna_Financial_Group')
#  + assign_('Zan',_'Sienna_Financial_Group') <= 5
#
# VARIABLES
# 0 <= assign_('Abeer',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Abeer',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Abeer',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Abeer',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Abeer',_'Innova') <= 1 Integer
# 0 <= assign_('Abeer',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Abeer',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Ayush',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Ayush',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Ayush',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Ayush',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Ayush',_'Innova') <= 1 Integer
# 0 <= assign_('Ayush',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Ayush',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Bonita',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Bonita',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Bonita',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Bonita',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Bonita',_'Innova') <= 1 Integer
# 0 <= assign_('Bonita',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Bonita',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Daria',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Daria',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Daria',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Daria',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Daria',_'Innova') <= 1 Integer
# 0 <= assign_('Daria',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Daria',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Elayne',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Elayne',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Elayne',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Elayne',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Elayne',_'Innova') <= 1 Integer
# 0 <= assign_('Elayne',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Elayne',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Jeroen',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Jeroen',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Jeroen',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Jeroen',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Jeroen',_'Innova') <= 1 Integer
# 0 <= assign_('Jeroen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Jeroen',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Kevin',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Kevin',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Kevin',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Kevin',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Kevin',_'Innova') <= 1 Integer
# 0 <= assign_('Kevin',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Kevin',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Kim',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Kim',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Kim',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Kim',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Kim',_'Innova') <= 1 Integer
# 0 <= assign_('Kim',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Kim',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Kristen',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Kristen',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Kristen',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Kristen',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Kristen',_'Innova') <= 1 Integer
# 0 <= assign_('Kristen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Kristen',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Segev',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Segev',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Segev',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Segev',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Segev',_'Innova') <= 1 Integer
# 0 <= assign_('Segev',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Segev',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Wei',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Wei',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Wei',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Wei',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Wei',_'Innova') <= 1 Integer
# 0 <= assign_('Wei',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Wei',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Yasmeen',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Innova') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Yasmeen',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Yilin',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yilin',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Yilin',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Yilin',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Yilin',_'Innova') <= 1 Integer
# 0 <= assign_('Yilin',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Yilin',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Yogesh',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Yogesh',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Yogesh',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Yogesh',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Yogesh',_'Innova') <= 1 Integer
# 0 <= assign_('Yogesh',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Yogesh',_'Sienna_Financial_Group') <= 1 Integer
# 0 <= assign_('Zan',_'CTG_Associates') <= 1 Integer
# 0 <= assign_('Zan',_'Celeron_Capital') <= 1 Integer
# 0 <= assign_('Zan',_'Felsen_Davis') <= 1 Integer
# 0 <= assign_('Zan',_'Helder_LLC') <= 1 Integer
# 0 <= assign_('Zan',_'Innova') <= 1 Integer
# 0 <= assign_('Zan',_'Quest_Realty') <= 1 Integer
# 0 <= assign_('Zan',_'Sienna_Financial_Group') <= 1 Integer

# %%
model.solve()
# Out:
# 1

# %%
model.solve()

LpStatus[model.status]
# Out:
# 'Optimal'

# %%
model.objective.value()
# Out:
# 1140.0

# %%
for v in model.variables(): 
    if v.varValue == 1 :
        print(f"{v.name}: {v.varValue}")
# Out:
# assign_('Abeer',_'Quest_Realty'): 1.0
# assign_('Abeer',_'Sienna_Financial_Group'): 1.0
# assign_('Ayush',_'Celeron_Capital'): 1.0
# assign_('Ayush',_'Innova'): 1.0
# assign_('Bonita',_'CTG_Associates'): 1.0
# assign_('Bonita',_'Celeron_Capital'): 1.0
# assign_('Daria',_'Innova'): 1.0
# assign_('Daria',_'Sienna_Financial_Group'): 1.0
# assign_('Elayne',_'Felsen_Davis'): 1.0
# assign_('Elayne',_'Innova'): 1.0
# assign_('Jeroen',_'Helder_LLC'): 1.0
# assign_('Jeroen',_'Quest_Realty'): 1.0
# assign_('Kevin',_'Felsen_Davis'): 1.0
# assign_('Kevin',_'Quest_Realty'): 1.0
# assign_('Kim',_'Celeron_Capital'): 1.0
# assign_('Kim',_'Helder_LLC'): 1.0
# assign_('Kristen',_'Celeron_Capital'): 1.0
# assign_('Kristen',_'Quest_Realty'): 1.0
# assign_('Segev',_'Felsen_Davis'): 1.0
# assign_('Segev',_'Innova'): 1.0
# assign_('Wei',_'Celeron_Capital'): 1.0
# assign_('Wei',_'Helder_LLC'): 1.0
# assign_('Yasmeen',_'Helder_LLC'): 1.0
# assign_('Yasmeen',_'Sienna_Financial_Group'): 1.0
# assign_('Yilin',_'CTG_Associates'): 1.0
# assign_('Yilin',_'Felsen_Davis'): 1.0
# assign_('Yogesh',_'CTG_Associates'): 1.0
# assign_('Yogesh',_'Helder_LLC'): 1.0
# assign_('Zan',_'CTG_Associates'): 1.0
# assign_('Zan',_'Quest_Realty'): 1.0
